# %% [markdown]
# ## Basic imports

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
mpl.font_manager.findSystemFonts()
mpl.font_manager.findfont('Humor Sans')
# Out:
# 'C:\\Users\\jgraber\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Humor-Sans.ttf'

# %% [markdown]
# ## Locate the Matplotlib cache

# %%
import matplotlib as mpl
mpl.get_cachedir()
# Out:
# 'C:\\Users\\jgraber\\.matplotlib'

# %% [markdown]
# ## XKCD

# %%
x = [1, 2, 3, 4]
y = [7, 6, 1, 2]

with plt.xkcd():
    fig, ax = plt.subplots()
    ax.bar(x,y)
plt.show();
