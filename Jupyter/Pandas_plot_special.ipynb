# %% [markdown]
# ## Basic imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Parallel coordinates

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/pandas-dev/'
    'pandas/main/pandas/tests/io/data/csv/iris.csv'
)
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.parallel_coordinates(
    df, 'Name', color=('#556270', '#4ECDC4', '#C7F464')
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Radviz

# %%
df = pd.DataFrame(
    {
        'SepalLength': [6.5, 7.7, 5.1, 5.8, 7.6, 5.0, 5.4, 4.6, 6.7, 4.6],
        'SepalWidth': [3.0, 3.8, 3.8, 2.7, 3.0, 2.3, 3.0, 3.2, 3.3, 3.6],
        'PetalLength': [5.5, 6.7, 1.9, 5.1, 6.6, 3.3, 4.5, 1.4, 5.7, 1.0],
        'PetalWidth': [1.8, 2.2, 0.4, 1.9, 2.1, 1.0, 1.5, 0.2, 2.1, 0.2],
        'Category': [
            'virginica',
            'virginica',
            'setosa',
            'virginica',
            'virginica',
            'versicolor',
            'versicolor',
            'setosa',
            'virginica',
            'setosa'
        ]
    }
)
df
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth    Category
# 0          6.5         3.0          5.5         1.8   virginica
# 1          7.7         3.8          6.7         2.2   virginica
# 2          5.1         3.8          1.9         0.4      setosa
# 3          5.8         2.7          5.1         1.9   virginica
# 4          7.6         3.0          6.6         2.1   virginica
# 5          5.0         2.3          3.3         1.0  versicolor
# 6          5.4         3.0          4.5         1.5  versicolor
# 7          4.6         3.2          1.4         0.2      setosa
# 8          6.7         3.3          5.7         2.1   virginica
# 9          4.6         3.6          1.0         0.2      setosa

# %%
pd.plotting.radviz(df, 'Category')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Scatter Matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
df
# Out:
#             A         B         C         D
# 0    0.631998 -0.336883 -1.506804  0.060048
# 1    0.375015 -0.060073 -0.760536 -0.069313
# 2    0.827847  0.935569 -0.959392  0.501844
# 3    0.570055 -0.811780 -0.117542 -0.489427
# 4    0.763947 -0.213076 -1.989740  2.720969
# ..        ...       ...       ...       ...
# 995  0.601236  1.811791  0.231572 -0.643406
# 996 -0.175841 -0.908863 -1.059250  0.946320
# 997 -1.442544  1.010473  0.293698 -0.881194
# 998  0.826541  1.796705  2.619376 -0.560288
# 999 -1.278636 -0.853868 -0.839427  0.969155
#
# [1000 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(df, alpha=0.5)
# Out:
# array([[<AxesSubplot: xlabel='A', ylabel='A'>,
#         <AxesSubplot: xlabel='B', ylabel='A'>,
#         <AxesSubplot: xlabel='C', ylabel='A'>,
#         <AxesSubplot: xlabel='D', ylabel='A'>],
#        [<AxesSubplot: xlabel='A', ylabel='B'>,
#         <AxesSubplot: xlabel='B', ylabel='B'>,
#         <AxesSubplot: xlabel='C', ylabel='B'>,
#         <AxesSubplot: xlabel='D', ylabel='B'>],
#        [<AxesSubplot: xlabel='A', ylabel='C'>,
#         <AxesSubplot: xlabel='B', ylabel='C'>,
#         <AxesSubplot: xlabel='C', ylabel='C'>,
#         <AxesSubplot: xlabel='D', ylabel='C'>],
#        [<AxesSubplot: xlabel='A', ylabel='D'>,
#         <AxesSubplot: xlabel='B', ylabel='D'>,
#         <AxesSubplot: xlabel='C', ylabel='D'>,
#         <AxesSubplot: xlabel='D', ylabel='D'>]], dtype=object)
