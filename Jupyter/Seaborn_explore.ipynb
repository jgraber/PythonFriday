# %% [markdown]
# ## Basic imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import os
data_file = os.path.abspath(os.path.join(os.getcwd(), 'data', 'diamonds.csv'))

# %% [markdown]
# ## Find the included datasets

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Load the diamonds dataset

# %%
diamond = sns.load_dataset("diamonds")

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# ## Pairplot
# Compares all numeric values with each other

# %%
sns.pairplot(diamond, plot_kws=dict(marker='+', linewidth=1))
#plt.savefig('pair.png')

# %% [markdown]
# ## Scatter Plot

# %%
f, ax = plt.subplots(figsize=(11, 8))
sns.scatterplot(x='carat', 
                y='price', 
                hue='cut', 
                size='clarity', 
                data=diamond, ax=ax)
#plt.savefig('scatter.png')

# %%
sns.scatterplot(x='carat', y='price', hue='cut', size='clarity', data=diamond)
sns.rugplot(x='carat', y='price', hue='cut', data=diamond)
# Out:
# <AxesSubplot: xlabel='carat', ylabel='price'>

# %%
sns.boxplot(x='carat', y='cut', data=diamond, color='yellow', width=0.5)
# Out:
# <AxesSubplot: xlabel='carat', ylabel='cut'>

# %%
sns.boxplot(x='carat', y='color', data=diamond, color='olive', width=0.5, linewidth=2.5)
# Out:
# <AxesSubplot: xlabel='carat', ylabel='color'>

# %%
sns.boxplot(x='carat', y='clarity', data=diamond, color='green', width=0.5, linewidth=2.5)
# Out:
# <AxesSubplot: xlabel='carat', ylabel='clarity'>

# %%
#sns.heatmap(diamond[['carat','price','depth']], linecolor='white', linewidths=2,annot=True)

# %%
sns.relplot(x="carat", y="price", hue="clarity", data=diamond)

# %%
sns.stripplot(x="cut", y="price", hue="carat", data=df)

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
#clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                #hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamond, ax=ax, palette="hls")
# Out:
# <AxesSubplot: xlabel='carat', ylabel='price'>
