# %% [markdown]
# ## Basic imports

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line plot

# %%
x = [1, 2, 3, 4]
y = [0, 6, 1, 2]
fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# ## Bar chart

# %%
month = ['January', 'February', 'March', 'April', 'May', 'June']
temp_average = [3.4, 5.2, 10.3, 14.5, 18.6, 22.5]

fig, ax = plt.subplots()
ax.bar(month, temp_average)
# Out:
# <BarContainer object of 6 artists>

# %%
month = ['January', 'February', 'March', 'April', 'May', 'June']
temp_average = [3.4, 5.2, 10.3, 14.5, 18.6, 22.5]

fig, ax = plt.subplots()
ax.barh(month, temp_average)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## Pie chart
# see https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html

# %%
labels = 'Cats', 'Dogs'
sizes = [65, 30]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x21554fe2a90>,
#   <matplotlib.patches.Wedge at 0x21555067650>],
#  [Text(-0.6016430102375324, 0.9208831023709364, 'Cats'),
#   Text(0.6016430102375327, -0.9208831023709363, 'Dogs')])

# %% [markdown]
# ## Scatter plot
# see https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html#scatter-plot

# %%
x = [1, 2, 3, 4, 3, 2, 2.5]
y = [0, 6, 1, 2, 5, 4, 2.5]

fig, ax = plt.subplots()
ax.scatter(x, y)

# %%
import numpy as np
# Fixing random state for reproducibility
np.random.seed(19680801)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

fig, ax = plt.subplots()
ax.scatter(x, y, s=area, c=colors, alpha=0.5)

# %% [markdown]
# ## Box plot
# see https://matplotlib.org/stable/gallery/statistics/boxplot_demo.html
# and https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
data =  [1, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 5, 5, 6] 

fig, ax = plt.subplots()
ax.boxplot(data)
#fig.savefig('Box.png', transparent=False, dpi=200, bbox_inches="tight")
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x215582a0f50>,
#   <matplotlib.lines.Line2D at 0x215582a1810>],
#  'caps': [<matplotlib.lines.Line2D at 0x215582a20d0>,
#   <matplotlib.lines.Line2D at 0x215582a2950>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21554fc7ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x215582a3190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x215582a3950>],
#  'means': []}

# %%
data =  [1, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 5, 5, 6] 

fig, ax = plt.subplots()
ax.boxplot(data, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x215582f6c50>,
#   <matplotlib.lines.Line2D at 0x215582f7890>],
#  'caps': [<matplotlib.lines.Line2D at 0x21558308290>,
#   <matplotlib.lines.Line2D at 0x21558308d50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x215582f6150>],
#  'medians': [<matplotlib.lines.Line2D at 0x21558309890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2155830a210>],
#  'means': []}

# %% [markdown]
# ## Histogram
# see https://matplotlib.org/stable/plot_types/stats/hist_plot.html#sphx-glr-plot-types-stats-hist-plot-py

# %%
data =  [1, 1, 2, 2, 2, 3, 3, 3, 3, 3, 3, 4, 4, 5, 5, 5, 5, 5, 6, 6] 

fig, ax = plt.subplots()
ax.hist(data, bins=6)
# Out:
# (array([2., 3., 6., 2., 5., 2.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# ## Grouped bar chart
# see https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html

# %%
import numpy as np
months = ['January', 'February', 'March', 'April', 'May', 'June']
temp_average = {
    'day': np.array([3.4, 5.2, 10.3, 14.5, 18.6, 22.5]),
    'night': np.array([-2.9, -2.8, 0.3, 3.4, 7.6, 11.3])
}

x = np.arange(len(months))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(constrained_layout=True)

for attribute, measurement in temp_average.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Ø Temperature (°C)')
ax.set_title('Temperature averages in Bern, Switzerland')
ax.set_xticks(x + width, months)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(-5, 25)

plt.show()

# %%
temp_average["day"]
# Out:
# array([ 3.4,  5.2, 10.3, 14.5, 18.6, 22.5])

# %%
fig, ax = plt.subplots()
ax.plot(months, temp_average["day"])
ax.plot(months, temp_average["night"])
