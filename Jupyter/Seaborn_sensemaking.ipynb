# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.sample(5)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 124  Adelie  Torgersen            35.2           15.9              186.0
# 263  Gentoo     Biscoe            49.6           15.0              216.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 249  Gentoo     Biscoe            50.0           15.3              220.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex
# 124       3050.0  Female
# 263       4750.0    Male
# 49        4150.0    Male
# 249       5550.0    Male
# 342       5200.0  Female

# %%
sns.pairplot(penguins)

# %%
sns.scatterplot(x='flipper_length_mm', y='bill_depth_mm', hue='sex', data=penguins)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(x='flipper_length_mm', y='bill_depth_mm', hue='species', data=penguins)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 103       22.42  3.48  Female    Yes  Sat  Dinner     2
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2
# 210       30.06  2.00    Male    Yes  Sat  Dinner     3
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2

# %%
sns.pairplot(tips)

# %%
sns.relplot(x="day", y="tip", hue="sex", data=tips)

# %%
sns.swarmplot(x="day", y="tip", hue="sex", data=tips)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot(index="month", columns="year", values="passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>
